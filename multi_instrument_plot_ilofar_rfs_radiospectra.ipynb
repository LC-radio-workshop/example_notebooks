# %% [markdown]
# ### Ground and Space radio observations of the same event with RadioSpectra

# %% [markdown]
# This notebook demonstrates the use of [RadioSpectra](https://github.com/sunpy/radiospectra) to download, load and plot an individual radio event observed across ground and space-based observatories.

# %% [markdown]
# Installation/Environment Notes

# %%
### Basic Imports
from radiospectra import net
from sunpy.net import Fido, attrs as a
from radiospectra.spectrogram import Spectrogram
from radiospectra.net import attrs as ra
import datetime
import numpy as np
import astropy.table
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, Normalize

# %% [markdown]
# We will download and load data from a very complex Type II,III,IV radio burst event which occurred around 16:40UT 2025/5/14. Various papers have been published on this event including: [Nedal et al. 2026](https://ui.adsabs.harvard.edu/abs/2026A%26A...708A..74N/abstract)

# %%
import radiospectra; print(radiospectra.__version__)
import sunpy; print(sunpy.__version__)
# Out:
# 0.6.1
# 7.1.2

# %%
# Define start and end times to load
dt_start = datetime.datetime(2024,5,14,16,30)
dt_end = datetime.datetime(2024,5,14,19)

# %% [markdown]
# #### Accessing I-Lofar Data
#
# RadioSpectra provides a `sunpy.net.Fido` client to search and download I-Lofar FITS dynamic spectrum data from this repository: https://lofar.ie/data-format/ with standard usage:

# %%
### I-LOFAR
query = Fido.search(a.Time(dt_start,dt_end),
                   a.Instrument('ILOFAR'), 
                   )
query
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x71c3161d00e0>
# Results from 1 Provider:
#
# 0 Results from the ILOFARMode357Client:
# Errors: Replacement index 6 out of range for positional args tuple
#
# <No columns>

# %% [markdown]
# Unfortunately for this particular event, the file we need is in different sub-folder to where the iLOFAR client currently checks. As of May 21 2026, a [GitHub issue](https://github.com/sunpy/radiospectra/issues/200) is open to enable Fido to check the other subdirectory.
#
# If the query was successful, the file could be downloaded with Fido.fetch as:

# %%
# ilofar_files = Fido.fetch(query)

# %% [markdown]
# For the present use-case, we will assume a user has manually downloaded the file to the sample_data subfolder in this repository. The url for this file (~130MB) is :
#
# https://data.lofar.ie/2024/05/14/bst/kbt/rcu357_1beam_datastream_fast/20240514_100136_bst_00X.dat

# %% [markdown]
# ### Read the i-LOFAR data
#
# Once the FITS file is available locally, it can be read directly with the `radiospectra.Spectrogram` container as:

# %%
# Here we provide a path manually
ilofar_Spectrograms = Spectrogram("./sample_data/20240514_100136_bst_00X.dat")

# %% [markdown]
# If the Fido query was successful, this manual filepath specification could be avoided and instead the file loaded into your session with the following commented out line.

# %%
# ilofar_Spectrograms = Spectrogram(ilofar_files)

# %% [markdown]
# #### Plot the i-LOFAR data
#
# With the i-LOFAR data parsed into the notebook, it can simply be plotted under default settings as:

# %%
fig,ax = plt.subplots(figsize=(10,5))
[spec.plot(axes=ax) for spec in ilofar_Spectrograms] #plot in loop in case multiple Spectrograms were loaded
ax.set_xlim(dt_start,dt_end)
# Out:
# (19857.6875, 19857.791666666668)

# %% [markdown]
# With regular `matplotlib` commands, the event structure can be better emphasized:

# %%
fig,ax = plt.subplots(figsize=(10,6))
[spec.plot(axes=ax,
           norm=LogNorm(spec.data.min(),spec.data.max()), # Log-Normalize Colorscale
           cmap="RdYlBu_r") # Colormap from Nedat+2026
 for spec in ilofar_Spectrograms]
ax.set_xlim(dt_start,dt_end)
ax.set_yscale("log")
ax.set_ylim(10,200)
# Out:
# (10, 200)

# %% [markdown]
# So we can see what the event looked like low in the corona (~10-200 MHz), but what about out in space?

# %% [markdown]
# ### Querying, Downloading and Plotting Parker Solar Probe FIELDS/RFS data

# %% [markdown]
# Staying within the `radiospectra` ecosystem, we can easily perform the same download/load/plot steps for Parker Solar Probe RFS instead (see also: `./psp_analysis.ipynb` and `./plot_psp.ipynb` in this directrory).
#
# First: query the RFS data
#
# These first lines use the RadioSpectra RFS Client, but this is currently broken in sunpy>=7.0.0 so we get no results
#
# Note that as compared to ground based instruments where files tend to be shorter than a day, RFS files are 1 per day. This is a something to remember when combining ground and spacecraft radio data: If we are looking at an event of order hours, we will typically be stitching together multiple ground based spectogram files, while for space based, we load a full day and then slice out a subset of it for the desired timerange.

# %%
### FIELDS/RFS L2 Data 

query = Fido.search(a.Time(datetime.datetime(2024,5,13),dt_end),a.Instrument("rfs"))
query
# Out:
# <sunpy.net.fido_factory.UnifiedResponse object at 0x71c30c99faa0>
# Results from 1 Provider:
#
# 0 Results from the RFSClient:
# Errors: Replacement index 7 out of range for positional args tuple
#
# <No columns>

# %% [markdown]
# Instead we can get the same files via the CDAWEB Fido client (sunpy core)

# %%
query = Fido.search(a.Time(dt_start,dt_end),
                    (a.cdaweb.Dataset("PSP_FLD_L2_RFS_HFR") | # Note that RFS has two frequency bands, hfr and lfr
                     a.cdaweb.Dataset("PSP_FLD_L2_RFS_LFR")   # Therefore we query both for the same date
                    ))
query

# %% [markdown]
# Notes:
#
# * L3 RFS data can be accessed via CDAWEB just by changing the above data types to "L3" rather than "L2",  but these files are  not yet handled by the `radiospectra` RFS Spectrogram subclass
#
# * We can examine the full list of available CDAWEB Datasets Fido can query:

# %%
print(a.cdaweb.Dataset)
# Out:
# sunpy.net.cdaweb.attrs.Dataset
#
# Dataset ID.
#
#
#                      Attribute Name                     ...
# ------------------------------------------------------- ...
# a1_k0_mpa                                               ...
# a2_k0_mpa                                               ...
# ac_at_def                                               ...
# ac_h0_mfi                                               ...
# ac_h0_swe                                               ...
# ac_h1_epm                                               ...
# ac_h1_mfi                                               ...
# ac_h1_sis                                               ...
# ac_h2_cris                                              ...
# ac_h2_epm                                               ...
# ac_h2_mfi                                               ...
# ac_h2_sep                                               ...
# ac_h2_sis                                               ...
# ac_h2_swe                                               ...
# ac_h2_swi                                               ...
# ac_h2_ule                                               ...
# ac_h3_cris                                              ...
# ac_h3_epm                                               ...
# ac_h3_mfi                                               ...
# ac_h3_sw2                                               ...
# ac_h3_swi                                               ...
# ac_h4_swi                                               ...
# ac_h5_swi                                               ...
# ac_h6_swi                                               ...
# ac_k0_epm                                               ...
# ac_k0_gifwalk                                           ...
# ac_k0_mfi                                               ...
# ac_k0_sis                                               ...
# ac_k0_swe                                               ...
# ac_k1_epm                                               ...
# ac_k1_mfi                                               ...
# ac_k1_swe                                               ...
# ac_k2_mfi                                               ...
# ac_or_def                                               ...
# ac_or_ssc                                               ...
# aerocube_6_a_dosimeter_l2                               ...
# aerocube_6_b_dosimeter_l2                               ...
# aim_cips_sci_3a                                         ...
# alouette2_av_lim                                        ...
# alouette2_av_qui                                        ...
# alouette2_av_snt                                        ...
# alouette2_av_sol                                        ...
# alouette2_av_ula                                        ...
# alouette2_av_wnk                                        ...
# alouette2_neprof_tops                                   ...
# amptecce_h0_mepa                                        ...
# apollo12_sws_1hr                                        ...
# apollo12_sws_28s                                        ...
# apollo15_sws_1hr                                        ...
# apollo15_sws_28s                                        ...
# awe_l3a_tmp                                             ...
# awe_l3c_q20                                             ...
# bar_1a_l2_ephm                                          ...
# bar_1a_l2_fspc                                          ...
# bar_1a_l2_hkpg                                          ...
# bar_1a_l2_magn                                          ...
# bar_1a_l2_mspc                                          ...
# bar_1a_l2_rcnt                                          ...
# bar_1a_l2_sspc                                          ...
# bar_1b_l2_ephm                                          ...
# bar_1b_l2_fspc                                          ...
# bar_1b_l2_hkpg                                          ...
# bar_1b_l2_magn                                          ...
# bar_1b_l2_mspc                                          ...
# bar_1b_l2_rcnt                                          ...
# bar_1b_l2_sspc                                          ...
# bar_1c_l2_ephm                                          ...
# bar_1c_l2_fspc                                          ...
# bar_1c_l2_hkpg                                          ...
# bar_1c_l2_magn                                          ...
# bar_1c_l2_mspc                                          ...
# bar_1c_l2_rcnt                                          ...
# bar_1c_l2_sspc                                          ...
# bar_1d_l2_ephm                                          ...
# bar_1d_l2_fspc                                          ...
# bar_1d_l2_hkpg                                          ...
# bar_1d_l2_magn                                          ...
# bar_1d_l2_mspc                                          ...
# bar_1d_l2_rcnt                                          ...
# bar_1d_l2_sspc                                          ...
# bar_1g_l2_ephm                                          ...
# bar_1g_l2_fspc                                          ...
# bar_1g_l2_hkpg                                          ...
# bar_1g_l2_magn                                          ...
# bar_1g_l2_mspc                                          ...
# bar_1g_l2_rcnt                                          ...
# bar_1g_l2_sspc                                          ...
# bar_1h_l2_ephm                                          ...
# bar_1h_l2_fspc                                          ...
# bar_1h_l2_hkpg                                          ...
# bar_1h_l2_magn                                          ...
# bar_1h_l2_mspc                                          ...
# bar_1h_l2_rcnt                                          ...
# bar_1h_l2_sspc                                          ...
# bar_1i_l2_ephm                                          ...
# bar_1i_l2_fspc                                          ...
# bar_1i_l2_hkpg                                          ...
# bar_1i_l2_magn                                          ...
# bar_1i_l2_mspc                                          ...
# bar_1i_l2_rcnt                                          ...
# bar_1i_l2_sspc                                          ...
# bar_1j_l2_ephm                                          ...
# bar_1j_l2_fspc                                          ...
# bar_1j_l2_hkpg                                          ...
# bar_1j_l2_magn                                          ...
# bar_1j_l2_mspc                                          ...
# bar_1j_l2_rcnt                                          ...
# bar_1j_l2_sspc                                          ...
# bar_1k_l2_ephm                                          ...
# bar_1k_l2_fspc                                          ...
# bar_1k_l2_hkpg                                          ...
# bar_1k_l2_magn                                          ...
# bar_1k_l2_mspc                                          ...
# bar_1k_l2_rcnt                                          ...
# bar_1k_l2_sspc                                          ...
# bar_1m_l2_ephm                                          ...
# bar_1m_l2_fspc                                          ...
# bar_1m_l2_hkpg                                          ...
# bar_1m_l2_magn                                          ...
# bar_1m_l2_mspc                                          ...
# bar_1m_l2_rcnt                                          ...
# bar_1m_l2_sspc                                          ...
# bar_1n_l2_ephm                                          ...
# bar_1n_l2_fspc                                          ...
# bar_1n_l2_hkpg                                          ...
# bar_1n_l2_magn                                          ...
# bar_1n_l2_mspc                                          ...
# bar_1n_l2_rcnt                                          ...
# bar_1n_l2_sspc                                          ...
# bar_1o_l2_ephm                                          ...
# bar_1o_l2_fspc                                          ...
# bar_1o_l2_hkpg                                          ...
# bar_1o_l2_magn                                          ...
# bar_1o_l2_mspc                                          ...
# bar_1o_l2_rcnt                                          ...
# bar_1o_l2_sspc                                          ...
# bar_1q_l2_ephm                                          ...
# bar_1q_l2_fspc                                          ...
# bar_1q_l2_hkpg                                          ...
# bar_1q_l2_magn                                          ...
# bar_1q_l2_mspc                                          ...
# bar_1q_l2_rcnt                                          ...
# bar_1q_l2_sspc                                          ...
# bar_1r_l2_ephm                                          ...
# bar_1r_l2_fspc                                          ...
# bar_1r_l2_hkpg                                          ...
# bar_1r_l2_magn                                          ...
# bar_1r_l2_mspc                                          ...
# bar_1r_l2_rcnt                                          ...
# bar_1r_l2_sspc                                          ...
# bar_1s_l2_ephm                                          ...
# bar_1s_l2_fspc                                          ...
# bar_1s_l2_hkpg                                          ...
# bar_1s_l2_magn                                          ...
# bar_1s_l2_mspc                                          ...
# bar_1s_l2_rcnt                                          ...
# bar_1s_l2_sspc                                          ...
# bar_1t_l2_ephm                                          ...
# bar_1t_l2_fspc                                          ...
# bar_1t_l2_hkpg                                          ...
# bar_1t_l2_magn                                          ...
# bar_1t_l2_mspc                                          ...
# bar_1t_l2_rcnt                                          ...
# bar_1t_l2_sspc                                          ...
# bar_1u_l2_ephm                                          ...
# bar_1u_l2_fspc                                          ...
# bar_1u_l2_hkpg                                          ...
# bar_1u_l2_magn                                          ...
# bar_1u_l2_mspc                                          ...
# bar_1u_l2_rcnt                                          ...
# bar_1u_l2_sspc                                          ...
# bar_1v_l2_ephm                                          ...
# bar_1v_l2_fspc                                          ...
# bar_1v_l2_hkpg                                          ...
# bar_1v_l2_magn                                          ...
# bar_1v_l2_mspc                                          ...
# bar_1v_l2_rcnt                                          ...
# bar_1v_l2_sspc                                          ...
# bar_2a_l2_ephm                                          ...
# bar_2a_l2_fspc                                          ...
# bar_2a_l2_hkpg                                          ...
# bar_2a_l2_magn                                          ...
# bar_2a_l2_mspc                                          ...
# bar_2a_l2_rcnt                                          ...
# bar_2a_l2_sspc                                          ...
# bar_2b_l2_ephm                                          ...
# bar_2b_l2_fspc                                          ...
# bar_2b_l2_hkpg                                          ...
# bar_2b_l2_magn                                          ...
# bar_2b_l2_mspc                                          ...
# bar_2b_l2_rcnt                                          ...
# bar_2b_l2_sspc                                          ...
# bar_2c_l2_ephm                                          ...
# bar_2c_l2_fspc                                          ...
# bar_2c_l2_hkpg                                          ...
# bar_2c_l2_magn                                          ...
# bar_2c_l2_mspc                                          ...
# bar_2c_l2_rcnt                                          ...
# bar_2c_l2_sspc                                          ...
# bar_2d_l2_ephm                                          ...
# bar_2d_l2_fspc                                          ...
# bar_2d_l2_hkpg                                          ...
# bar_2d_l2_magn                                          ...
# bar_2d_l2_mspc                                          ...
# bar_2d_l2_rcnt                                          ...
# bar_2d_l2_sspc                                          ...
# bar_2e_l2_ephm                                          ...
# bar_2e_l2_fspc                                          ...
# bar_2e_l2_hkpg                                          ...
# bar_2e_l2_magn                                          ...
# bar_2e_l2_mspc                                          ...
# bar_2e_l2_rcnt                                          ...
# bar_2e_l2_sspc                                          ...
# bar_2f_l2_ephm                                          ...
# bar_2f_l2_fspc                                          ...
# bar_2f_l2_hkpg                                          ...
# bar_2f_l2_magn                                          ...
# bar_2f_l2_mspc                                          ...
# bar_2f_l2_rcnt                                          ...
# bar_2f_l2_sspc                                          ...
# bar_2i_l2_ephm                                          ...
# bar_2i_l2_fspc                                          ...
# bar_2i_l2_hkpg                                          ...
# bar_2i_l2_magn                                          ...
# bar_2i_l2_mspc                                          ...
# bar_2i_l2_rcnt                                          ...
# bar_2i_l2_sspc                                          ...
# bar_2k_l2_ephm                                          ...
# bar_2k_l2_fspc                                          ...
# bar_2k_l2_hkpg                                          ...
# bar_2k_l2_magn                                          ...
# bar_2k_l2_mspc                                          ...
# bar_2k_l2_rcnt                                          ...
# bar_2k_l2_sspc                                          ...
# bar_2l_l2_ephm                                          ...
# bar_2l_l2_fspc                                          ...
# bar_2l_l2_hkpg                                          ...
# bar_2l_l2_magn                                          ...
# bar_2l_l2_mspc                                          ...
# bar_2l_l2_rcnt                                          ...
# bar_2l_l2_sspc                                          ...
# bar_2m_l2_ephm                                          ...
# bar_2m_l2_fspc                                          ...
# bar_2m_l2_hkpg                                          ...
# bar_2m_l2_magn                                          ...
# bar_2m_l2_mspc                                          ...
# bar_2m_l2_rcnt                                          ...
# bar_2m_l2_sspc                                          ...
# bar_2n_l2_ephm                                          ...
# bar_2n_l2_fspc                                          ...
# bar_2n_l2_hkpg                                          ...
# bar_2n_l2_magn                                          ...
# bar_2n_l2_mspc                                          ...
# bar_2n_l2_rcnt                                          ...
# bar_2n_l2_sspc                                          ...
# bar_2o_l2_ephm                                          ...
# bar_2o_l2_fspc                                          ...
# bar_2o_l2_hkpg                                          ...
# bar_2o_l2_magn                                          ...
# bar_2o_l2_mspc                                          ...
# bar_2o_l2_rcnt                                          ...
# bar_2o_l2_sspc                                          ...
# bar_2p_l2_ephm                                          ...
# bar_2p_l2_fspc                                          ...
# bar_2p_l2_hkpg                                          ...
# bar_2p_l2_magn                                          ...
# bar_2p_l2_mspc                                          ...
# bar_2p_l2_rcnt                                          ...
# bar_2p_l2_sspc                                          ...
# bar_2q_l2_ephm                                          ...
# bar_2q_l2_fspc                                          ...
# bar_2q_l2_hkpg                                          ...
# bar_2q_l2_magn                                          ...
# bar_2q_l2_mspc                                          ...
# bar_2q_l2_rcnt                                          ...
# bar_2q_l2_sspc                                          ...
# bar_2t_l2_ephm                                          ...
# bar_2t_l2_fspc                                          ...
# bar_2t_l2_hkpg                                          ...
# bar_2t_l2_magn                                          ...
# bar_2t_l2_mspc                                          ...
# bar_2t_l2_rcnt                                          ...
# bar_2t_l2_sspc                                          ...
# bar_2w_l2_ephm                                          ...
# bar_2w_l2_fspc                                          ...
# bar_2w_l2_hkpg                                          ...
# bar_2w_l2_magn                                          ...
# bar_2w_l2_mspc                                          ...
# bar_2w_l2_rcnt                                          ...
# bar_2w_l2_sspc                                          ...
# bar_2x_l2_ephm                                          ...
# bar_2x_l2_fspc                                          ...
# bar_2x_l2_hkpg                                          ...
# bar_2x_l2_magn                                          ...
# bar_2x_l2_mspc                                          ...
# bar_2x_l2_rcnt                                          ...
# bar_2x_l2_sspc                                          ...
# bar_2y_l2_ephm                                          ...
# bar_2y_l2_fspc                                          ...
# bar_2y_l2_hkpg                                          ...
# bar_2y_l2_magn                                          ...
# bar_2y_l2_mspc                                          ...
# bar_2y_l2_rcnt                                          ...
# bar_2y_l2_sspc                                          ...
# bar_3a_l2_ephm                                          ...
# bar_3a_l2_fspc                                          ...
# bar_3a_l2_hkpg                                          ...
# bar_3a_l2_magn                                          ...
# bar_3a_l2_mspc                                          ...
# bar_3a_l2_rcnt                                          ...
# bar_3a_l2_sspc                                          ...
# bar_3b_l2_ephm                                          ...
# bar_3b_l2_fspc                                          ...
# bar_3b_l2_hkpg                                          ...
# bar_3b_l2_magn                                          ...
# bar_3b_l2_mspc                                          ...
# bar_3b_l2_rcnt                                          ...
# bar_3b_l2_sspc                                          ...
# bar_3c_l2_ephm                                          ...
# bar_3c_l2_fspc                                          ...
# bar_3c_l2_hkpg                                          ...
# bar_3c_l2_magn                                          ...
# bar_3c_l2_mspc                                          ...
# bar_3c_l2_rcnt                                          ...
# bar_3c_l2_sspc                                          ...
# bar_3d_l2_ephm                                          ...
# bar_3d_l2_fspc                                          ...
# bar_3d_l2_hkpg                                          ...
# bar_3d_l2_magn                                          ...
# bar_3d_l2_mspc                                          ...
# bar_3d_l2_rcnt                                          ...
# bar_3d_l2_sspc                                          ...
# bar_3e_l2_ephm                                          ...
# bar_3e_l2_fspc                                          ...
# bar_3e_l2_hkpg                                          ...
# bar_3e_l2_magn                                          ...
# bar_3e_l2_mspc                                          ...
# bar_3e_l2_rcnt                                          ...
# bar_3e_l2_sspc                                          ...
# bar_3f_l2_ephm                                          ...
# bar_3f_l2_fspc                                          ...
# bar_3f_l2_hkpg                                          ...
# bar_3f_l2_magn                                          ...
# bar_3f_l2_mspc                                          ...
# bar_3f_l2_rcnt                                          ...
# bar_3f_l2_sspc                                          ...
# bar_3g_l2_ephm                                          ...
# bar_3g_l2_fspc                                          ...
# bar_3g_l2_hkpg                                          ...
# bar_3g_l2_magn                                          ...
# bar_3g_l2_mspc                                          ...
# bar_3g_l2_rcnt                                          ...
# bar_3g_l2_sspc                                          ...
# bar_4a_l2_ephm                                          ...
# bar_4a_l2_fspc                                          ...
# bar_4a_l2_hkpg                                          ...
# bar_4a_l2_mspc                                          ...
# bar_4a_l2_rcnt                                          ...
# bar_4a_l2_sspc                                          ...
# bar_4a_l2_uspc                                          ...
# bar_4a_l2_xspc                                          ...
# bar_4b_l2_ephm                                          ...
# bar_4b_l2_fspc                                          ...
# bar_4b_l2_hkpg                                          ...
# bar_4b_l2_mspc                                          ...
# bar_4b_l2_rcnt                                          ...
# bar_4b_l2_sspc                                          ...
# bar_4b_l2_uspc                                          ...
# bar_4b_l2_xspc                                          ...
# bar_4c_l2_ephm                                          ...
# bar_4c_l2_fspc                                          ...
# bar_4c_l2_hkpg                                          ...
# bar_4c_l2_mspc                                          ...
# bar_4c_l2_rcnt                                          ...
# bar_4c_l2_sspc                                          ...
# bar_4c_l2_uspc                                          ...
# bar_4c_l2_xspc                                          ...
# bar_4d_l2_ephm                                          ...
# bar_4d_l2_fspc                                          ...
# bar_4d_l2_hkpg                                          ...
# bar_4d_l2_mspc                                          ...
# bar_4d_l2_rcnt                                          ...
# bar_4d_l2_sspc                                          ...
# bar_4d_l2_uspc                                          ...
# bar_4d_l2_xspc                                          ...
# bar_4e_l2_ephm                                          ...
# bar_4e_l2_fspc                                          ...
# bar_4e_l2_hkpg                                          ...
# bar_4e_l2_mspc                                          ...
# bar_4e_l2_rcnt                                          ...
# bar_4e_l2_sspc                                          ...
# bar_4e_l2_uspc                                          ...
# bar_4e_l2_xspc                                          ...
# bar_4f_l2_ephm                                          ...
# bar_4f_l2_fspc                                          ...
# bar_4f_l2_hkpg                                          ...
# bar_4f_l2_mspc                                          ...
# bar_4f_l2_rcnt                                          ...
# bar_4f_l2_sspc                                          ...
# bar_4f_l2_uspc                                          ...
# bar_4f_l2_xspc                                          ...
# bar_4g_l2_ephm                                          ...
# bar_4g_l2_fspc                                          ...
# bar_4g_l2_hkpg                                          ...
# bar_4g_l2_mspc                                          ...
# bar_4g_l2_rcnt                                          ...
# bar_4g_l2_sspc                                          ...
# bar_4g_l2_uspc                                          ...
# bar_4g_l2_xspc                                          ...
# bar_4h_l2_ephm                                          ...
# bar_4h_l2_fspc                                          ...
# bar_4h_l2_hkpg                                          ...
# bar_4h_l2_mspc                                          ...
# bar_4h_l2_rcnt                                          ...
# bar_4h_l2_sspc                                          ...
# bar_4h_l2_uspc                                          ...
# bar_4h_l2_xspc                                          ...
# bar_5a_l2_ephm                                          ...
# bar_5a_l2_fspc                                          ...
# bar_5a_l2_hkpg                                          ...
# bar_5a_l2_mspc                                          ...
# bar_5a_l2_rcnt                                          ...
# bar_5a_l2_sspc                                          ...
# bar_5a_l2_uspc                                          ...
# bar_5a_l2_xspc                                          ...
# bar_6a_l2_ephm                                          ...
# bar_6a_l2_fspc                                          ...
# bar_6a_l2_hkpg                                          ...
# bar_6a_l2_magn                                          ...
# bar_6a_l2_mspc                                          ...
# bar_6a_l2_rcnt                                          ...
# bar_6a_l2_sspc                                          ...
# bar_7a_l2_ephm                                          ...
# bar_7a_l2_fspc                                          ...
# bar_7a_l2_hkpg                                          ...
# bar_7a_l2_magn                                          ...
# bar_7a_l2_mspc                                          ...
# bar_7a_l2_rcnt                                          ...
# bar_7a_l2_sspc                                          ...
# bepicolombo_helio1day_position                          ...
# bepicolombo_helio1hr_position                           ...
# biosentinel_let_lets                                    ...
# borrelly_helio1day_position                             ...
# borrelly_helio1hr_position                              ...
# c1_cp_cis_codif_h1_1d_pef                               ...
# c1_cp_cis_codif_he1_1d_pef                              ...
# c1_cp_cis_codif_hs_h1_pef                               ...
# c1_cp_cis_codif_hs_h1_pf                                ...
# c1_cp_cis_codif_hs_h1_psd                               ...
# c1_cp_cis_codif_hs_he1_pf                               ...
# c1_cp_cis_codif_hs_he1_psd                              ...
# c1_cp_cis_codif_hs_o1_pef                               ...
# c1_cp_cis_codif_hs_o1_pf                                ...
# c1_cp_cis_codif_hs_o1_psd                               ...
# c1_cp_cis_codif_o1_1d_pef                               ...
# c1_cp_cis_codif_pad_hs_h1_pf                            ...
# c1_cp_cis_codif_pad_hs_he1_pf                           ...
# c1_cp_cis_codif_pad_hs_o1_pf                            ...
# c1_cp_cis_hia_hs_1d_pef                                 ...
# c1_cp_cis_hia_hs_mag_ions_pef                           ...
# c1_cp_cis_hia_hs_mag_ions_pf                            ...
# c1_cp_cis_hia_hs_mag_ions_psd                           ...
# c1_cp_cis_hia_hs_sw_ions_pef                            ...
# c1_cp_cis_hia_hs_sw_ions_pf                             ...
# c1_cp_cis_hia_hs_sw_ions_psd                            ...
# c1_cp_cis_hia_ls_1d_pef                                 ...
# c1_cp_cis_hia_ls_sw_ions_pef                            ...
# c1_cp_cis_hia_ls_sw_ions_pf                             ...
# c1_cp_cis_hia_ls_sw_ions_psd                            ...
# c1_cp_cis_hia_pad_hs_mag_ions_pf                        ...
# c1_cp_edi_aedc                                          ...
# c1_cp_edi_mp                                            ...
# c1_cp_edi_qzc                                           ...
# c1_cp_edi_spin                                          ...
# c1_cp_efw_l3_e3d_inert                                  ...
# c1_cp_efw_l3_p                                          ...
# c1_cp_efw_l3_v3d_inert                                  ...
# c1_cp_fgm_5vps                                          ...
# c1_cp_fgm_spin                                          ...
# c1_cp_rap_e3dd                                          ...
# c1_cp_rap_espct6                                        ...
# c1_cp_rap_hspct                                         ...
# c1_cp_rap_i3dm_cno                                      ...
# c1_cp_rap_i3dm_h                                        ...
# c1_cp_rap_i3dm_he                                       ...
# c1_cp_rap_ispct_cno                                     ...
# c1_cp_rap_ispct_he                                      ...
# c1_cp_rap_l3dd                                          ...
# c1_cp_rap_pad_cno                                       ...
# c1_cp_rap_pad_e3dd                                      ...
# c1_cp_rap_pad_h                                         ...
# c1_cp_rap_pad_he                                        ...
# c1_cp_rap_pad_l3dd                                      ...
# c1_cp_sta_cwf_gse                                       ...
# c1_cp_sta_ppp                                           ...
# c1_cp_sta_psd                                           ...
# c1_cp_sta_sm                                            ...
# c1_cp_whi_active                                        ...
# c1_cp_whi_electron_density                              ...
# c1_cp_whi_natural                                       ...
# c1_cp_whi_passive_active                                ...
# c1_cp_whi_wave_form_energy                              ...
# c1_jp_pmp                                               ...
# c1_jp_pse                                               ...
# c1_pp_asp                                               ...
# c1_pp_cis                                               ...
# c1_pp_dwp                                               ...
# c1_pp_edi                                               ...
# c1_pp_efw                                               ...
# c1_pp_pea                                               ...
# c1_pp_rap                                               ...
# c1_pp_sta                                               ...
# c1_pp_whi                                               ...
# c1_up_fgm                                               ...
# c1_waveform_wbd                                         ...
# c1_waveform_wbd_bm2                                     ...
# c2_cp_edi_aedc                                          ...
# c2_cp_edi_mp                                            ...
# c2_cp_edi_qzc                                           ...
# c2_cp_edi_spin                                          ...
# c2_cp_efw_l3_e3d_inert                                  ...
# c2_cp_efw_l3_p                                          ...
# c2_cp_efw_l3_v3d_inert                                  ...
# c2_cp_fgm_5vps                                          ...
# c2_cp_fgm_spin                                          ...
# c2_cp_rap_e3dd                                          ...
# c2_cp_rap_espct6                                        ...
# c2_cp_rap_hspct                                         ...
# c2_cp_rap_i3dm_cno                                      ...
# c2_cp_rap_i3dm_h                                        ...
# c2_cp_rap_i3dm_he                                       ...
# c2_cp_rap_ispct_cno                                     ...
# c2_cp_rap_ispct_he                                      ...
# c2_cp_rap_l3dd                                          ...
# c2_cp_rap_pad_e3dd                                      ...
# c2_cp_rap_pad_h                                         ...
# c2_cp_rap_pad_he                                        ...
# c2_cp_rap_pad_l3dd                                      ...
# c2_cp_sta_cwf_gse                                       ...
# c2_cp_sta_ppp                                           ...
# c2_cp_sta_psd                                           ...
# c2_cp_sta_sm                                            ...
# c2_cp_whi_active                                        ...
# c2_cp_whi_electron_density                              ...
# c2_cp_whi_natural                                       ...
# c2_cp_whi_passive_active                                ...
# c2_cp_whi_wave_form_energy                              ...
# c2_jp_pmp                                               ...
# c2_jp_pse                                               ...
# c2_pp_asp                                               ...
# c2_pp_dwp                                               ...
# c2_pp_edi                                               ...
# c2_pp_efw                                               ...
# c2_pp_pea                                               ...
# c2_pp_rap                                               ...
# c2_pp_sta                                               ...
# c2_pp_whi                                               ...
# c2_up_fgm                                               ...
# c2_waveform_wbd                                         ...
# c2_waveform_wbd_bm2                                     ...
# c3_cp_cis_codif_h1_1d_pef                               ...
# c3_cp_cis_codif_he1_1d_pef                              ...
# c3_cp_cis_codif_hs_h1_pef                               ...
# c3_cp_cis_codif_hs_h1_pf                                ...
# c3_cp_cis_codif_hs_h1_psd                               ...
# c3_cp_cis_codif_hs_he1_pf                               ...
# c3_cp_cis_codif_hs_he1_psd                              ...
# c3_cp_cis_codif_hs_o1_pef                               ...
# c3_cp_cis_codif_hs_o1_pf                                ...
# c3_cp_cis_codif_hs_o1_psd                               ...
# c3_cp_cis_codif_o1_1d_pef                               ...
# c3_cp_cis_codif_pad_hs_h1_pf                            ...
# c3_cp_cis_codif_pad_hs_he1_pf                           ...
# c3_cp_cis_codif_pad_hs_o1_pf                            ...
# c3_cp_cis_hia_hs_1d_pef                                 ...
# c3_cp_cis_hia_hs_mag_ions_pef                           ...
# c3_cp_cis_hia_hs_mag_ions_pf                            ...
# c3_cp_cis_hia_hs_mag_ions_psd                           ...
# c3_cp_cis_hia_hs_sw_ions_pef                            ...
# c3_cp_cis_hia_hs_sw_ions_pf                             ...
# c3_cp_cis_hia_hs_sw_ions_psd                            ...
# c3_cp_cis_hia_ls_1d_pef                                 ...
# c3_cp_cis_hia_ls_sw_ions_pef                            ...
# c3_cp_cis_hia_ls_sw_ions_pf                             ...
# c3_cp_cis_hia_ls_sw_ions_psd                            ...
# c3_cp_cis_hia_pad_hs_mag_ions_pf                        ...
# c3_cp_edi_aedc                                          ...
# c3_cp_edi_mp                                            ...
# c3_cp_edi_qzc                                           ...
# c3_cp_edi_spin                                          ...
# c3_cp_efw_l3_e3d_inert                                  ...
# c3_cp_efw_l3_p                                          ...
# c3_cp_efw_l3_v3d_inert                                  ...
# c3_cp_fgm_5vps                                          ...
# c3_cp_fgm_spin                                          ...
# c3_cp_rap_e3dd                                          ...
# c3_cp_rap_espct6                                        ...
# c3_cp_rap_hspct                                         ...
# c3_cp_rap_i3dm_cno                                      ...
# c3_cp_rap_i3dm_h                                        ...
# c3_cp_rap_i3dm_he                                       ...
# c3_cp_rap_ispct_cno                                     ...
# c3_cp_rap_ispct_he                                      ...
# c3_cp_rap_l3dd                                          ...
# c3_cp_rap_pad_cno                                       ...
# c3_cp_rap_pad_e3dd                                      ...
# c3_cp_rap_pad_h                                         ...
# c3_cp_rap_pad_he                                        ...
# c3_cp_rap_pad_l3dd                                      ...
# c3_cp_sta_cwf_gse                                       ...
# c3_cp_sta_ppp                                           ...
# c3_cp_sta_psd                                           ...
# c3_cp_sta_sm                                            ...
# c3_cp_whi_active                                        ...
# c3_cp_whi_electron_density                              ...
# c3_cp_whi_natural                                       ...
# c3_cp_whi_passive_active                                ...
# c3_cp_whi_wave_form_energy                              ...
# c3_jp_pmp                                               ...
# c3_jp_pse                                               ...
# c3_pp_asp                                               ...
# c3_pp_cis                                               ...
# c3_pp_edi                                               ...
# c3_pp_efw                                               ...
# c3_pp_pea                                               ...
# c3_pp_rap                                               ...
# c3_pp_sta                                               ...
# c3_pp_whi                                               ...
# c3_up_fgm                                               ...
# c3_waveform_wbd                                         ...
# c3_waveform_wbd_bm2                                     ...
# c4_cp_cis_codif_h1_1d_pef                               ...
# c4_cp_cis_codif_he1_1d_pef                              ...
# c4_cp_cis_codif_he1_density_corrected                   ...
# c4_cp_cis_codif_hs_h1_pef                               ...
# c4_cp_cis_codif_hs_h1_pf                                ...
# c4_cp_cis_codif_hs_h1_psd                               ...
# c4_cp_cis_codif_hs_he1_pf                               ...
# c4_cp_cis_codif_hs_he1_psd                              ...
# c4_cp_cis_codif_hs_o1_pef                               ...
# c4_cp_cis_codif_hs_o1_pf                                ...
# c4_cp_cis_codif_hs_o1_psd                               ...
# c4_cp_cis_codif_ls_h1_pef                               ...
# c4_cp_cis_codif_ls_h1_pf                                ...
# c4_cp_cis_codif_ls_h1_psd                               ...
# c4_cp_cis_codif_ls_he1_pef                              ...
# c4_cp_cis_codif_ls_he1_pf                               ...
# c4_cp_cis_codif_ls_o1_pef                               ...
# c4_cp_cis_codif_ls_o1_pf                                ...
# c4_cp_cis_codif_ls_o1_psd                               ...
# c4_cp_cis_codif_o1_1d_pef                               ...
# c4_cp_cis_codif_pad_hs_h1_pf                            ...
# c4_cp_cis_codif_pad_hs_he1_pf                           ...
# c4_cp_cis_codif_pad_hs_o1_pf                            ...
# c4_cp_cis_codif_pad_ls_h1_pf                            ...
# c4_cp_cis_codif_pad_ls_he1_pf                           ...
# c4_cp_cis_codif_pad_ls_o1_pf                            ...
# c4_cp_efw_l3_e3d_inert                                  ...
# c4_cp_efw_l3_p                                          ...
# c4_cp_efw_l3_v3d_inert                                  ...
# c4_cp_fgm_5vps                                          ...
# c4_cp_fgm_spin                                          ...
# c4_cp_rap_e3dd                                          ...
# c4_cp_rap_espct6                                        ...
# c4_cp_rap_hspct                                         ...
# c4_cp_rap_i3dm_cno                                      ...
# c4_cp_rap_i3dm_h                                        ...
# c4_cp_rap_i3dm_he                                       ...
# c4_cp_rap_ispct_cno                                     ...
# c4_cp_rap_ispct_he                                      ...
# c4_cp_rap_l3dd                                          ...
# c4_cp_rap_pad_cno                                       ...
# c4_cp_rap_pad_e3dd                                      ...
# c4_cp_rap_pad_h                                         ...
# c4_cp_rap_pad_he                                        ...
# c4_cp_rap_pad_l3dd                                      ...
# c4_cp_sta_cwf_gse                                       ...
# c4_cp_sta_ppp                                           ...
# c4_cp_sta_psd                                           ...
# c4_cp_sta_sm                                            ...
# c4_cp_whi_active                                        ...
# c4_cp_whi_electron_density                              ...
# c4_cp_whi_natural                                       ...
# c4_cp_whi_passive_active                                ...
# c4_cp_whi_wave_form_energy                              ...
# c4_jp_pmp                                               ...
# c4_jp_pse                                               ...
# c4_pp_asp                                               ...
# c4_pp_cis                                               ...
# c4_pp_dwp                                               ...
# c4_pp_edi                                               ...
# c4_pp_efw                                               ...
# c4_pp_pea                                               ...
# c4_pp_rap                                               ...
# c4_pp_sta                                               ...
# c4_pp_whi                                               ...
# c4_up_fgm                                               ...
# c4_waveform_wbd                                         ...
# c4_waveform_wbd_bm2                                     ...
# cassini_helio1day_position                              ...
# cassini_helio1hr_position                               ...
# cassini_mag_1min_magnetic_field                         ...
# cirbe_reptile_2_l1a_detectors                           ...
# cirbe_reptile_2_l1b_rng_elecs                           ...
# cirbe_reptile_2_l2_rng_elecs                            ...
# cl_jp_pcy                                               ...
# cl_jp_pgp                                               ...
# cl_or_gifwalk                                           ...
# cl_sp_aux                                               ...
# cn_k0_asi                                               ...
# cn_k0_bars                                              ...
# cn_k0_mari                                              ...
# cn_k0_mpa                                               ...
# cn_k1_mari                                              ...
# cnofs_cindi_ivm_500ms                                   ...
# cnofs_plp_plasma_1sec                                   ...
# cnofs_vefi_bfield_1sec                                  ...
# cnofs_vefi_efield_1sec                                  ...
# cnofs_vefi_ld_500ms                                     ...
# cometgs_helio1day_position                              ...
# cometgs_helio1hr_position                               ...
# comethmp_helio1day_position                             ...
# comethmp_helio1hr_position                              ...
# crres_h0_mea                                            ...
# csswe_reptile_6sec_counts_l1                            ...
# csswe_reptile_6sec_flux_l2                              ...
# ct_jp_pse                                               ...
# dawn_helio1day_position                                 ...
# dawn_helio1hr_position                                  ...
# de1_1min_rims                                           ...
# de1_2sec_oa                                             ...
# de1_62ms_maga_gms                                       ...
# de1_6sec_magagms                                        ...
# de1_pwi_lfc_spectra                                     ...
# de1_pwi_or_at                                           ...
# de1_pwi_sfc_spectra                                     ...
# de2_62ms_vefimagb                                       ...
# de2_ac500ms_vefi                                        ...
# de2_dca500ms_vefi                                       ...
# de2_duct16ms_rpa                                        ...
# de2_ion2s_rpa                                           ...
# de2_lapi_electron_flux_counts_pps1                      ...
# de2_lapi_electron_flux_counts_pps2                      ...
# de2_lapi_geiger_mueller                                 ...
# de2_lapi_geiger_mueller_ratio                           ...
# de2_lapi_ion_flux_counts_pps1                           ...
# de2_lapi_ion_flux_counts_pps2                           ...
# de2_lapi_lapi_mag                                       ...
# de2_lapi_orbit_attitude                                 ...
# de2_lapi_orbit_attitude_magb                            ...
# de2_lapi_pitch_angles                                   ...
# de2_lapi_projected_magb                                 ...
# de2_lapi_sc_magb                                        ...
# de2_lapi_shaft_encoder_angle                            ...
# de2_neutral1s_nacs                                      ...
# de2_neutral8s_fpi                                       ...
# de2_plasma500ms_lang                                    ...
# de2_ua16s_all                                           ...
# de2_vion250ms_idm                                       ...
# de2_wind2s_wats                                         ...
# de_uv_sai                                               ...
# de_vs_eics                                              ...
# dmsp_f06_ssj_precipitating_electrons_ions               ...
# dmsp_f07_ssj_precipitating_electrons_ions               ...
# dmsp_f08_ssj_precipitating_electrons_ions               ...
# dmsp_f09_ssj_precipitating_electrons_ions               ...
# dmsp_f12_ssj_precipitating_electrons_ions               ...
# dmsp_f13_ssj_precipitating_electrons_ions               ...
# dmsp_f14_ssj_precipitating_electrons_ions               ...
# dmsp_f15_ssj_precipitating_electrons_ions               ...
# dmsp_f16_ssies_3_thermal_plasma                         ...
# dmsp_f16_ssj_precipitating_electrons_ions               ...
# dmsp_f16_ssm_magnetometer                               ...
# dmsp_f17_ssies_3_thermal_plasma                         ...
# dmsp_f17_ssj_precipitating_electrons_ions               ...
# dmsp_f17_ssm_magnetometer                               ...
# dmsp_f18_ssies_3_thermal_plasma                         ...
# dmsp_f18_ssj_precipitating_electrons_ions               ...
# dmsp_f18_ssm_magnetometer                               ...
# dmsp_r0_ssies                                           ...
# dmsp_r0_ssj4                                            ...
# dmspf16_r0_ssusi                                        ...
# dmspf17_r0_ssusi                                        ...
# dmspf18_r0_ssusi                                        ...
# dn_k0_gbay                                              ...
# dn_k0_hank                                              ...
# dn_k0_icew                                              ...
# dn_k0_kapu                                              ...
# dn_k0_pace                                              ...
# dn_k0_pykk                                              ...
# dn_k0_sask                                              ...
# dn_magn_l2_hires_g08                                    ...
# dn_magn_l2_hires_g09                                    ...
# dn_magn_l2_hires_g10                                    ...
# dn_magn_l2_hires_g11                                    ...
# dn_magn_l2_hires_g12                                    ...
# dn_magn_l2_hires_g13                                    ...
# ...
# tss_1r_m1_shaa                                          ...
# tss_1r_m1_shab                                          ...
# tss_1r_m1_shac                                          ...
# tss_1r_m1_shad                                          ...
# tss_1r_m1_shae                                          ...
# tss_1r_m1_shaf                                          ...
# tss_1r_m1_shag                                          ...
# tss_1r_m1_shha                                          ...
# tss_1r_m1_shhb                                          ...
# tss_1r_m1_shhc                                          ...
# tss_1r_m1_shhd                                          ...
# tss_1r_m1_shhe                                          ...
# tss_1r_m1_shhf                                          ...
# tss_1r_m1_shma                                          ...
# tss_1r_m1_shmb                                          ...
# tss_1r_m1_shmc                                          ...
# tss_1r_m1_shmd                                          ...
# tss_1r_m1_shme                                          ...
# tss_1r_m1_shpa                                          ...
# tss_1r_m1_shsa                                          ...
# tss_1r_m1_shsb                                          ...
# tss_1r_m1_shsc                                          ...
# tss_1r_m1_shsd                                          ...
# tss_1r_m1_shse                                          ...
# tss_1r_m1_shsf                                          ...
# tss_1r_m1_shsg                                          ...
# tss_1r_m1_shsh                                          ...
# tss_1r_m1_shsi                                          ...
# tss_1r_m1_shsj                                          ...
# tss_1r_m1_shsk                                          ...
# tss_1r_m1_shta                                          ...
# tss_1r_m1_shtb                                          ...
# tss_1r_m1_shtc                                          ...
# tss_1r_m1_spba                                          ...
# tss_1r_m1_spea                                          ...
# tss_1r_m1_speb                                          ...
# tss_1r_m1_spec                                          ...
# tss_1r_m1_sped                                          ...
# tss_1r_m1_spfa                                          ...
# tss_1r_m1_spfb                                          ...
# tss_1r_m1_spha                                          ...
# tss_1r_m1_sphb                                          ...
# tss_1r_m1_sphc                                          ...
# tss_1r_m1_sphd                                          ...
# tss_1r_m1_sphe                                          ...
# tss_1r_m1_spia                                          ...
# tss_1r_m1_spib                                          ...
# tss_1r_m1_spic                                          ...
# tss_1r_m1_spid                                          ...
# tss_1r_m1_spie                                          ...
# tss_1r_m1_spif                                          ...
# tss_1r_m1_spla                                          ...
# tss_1r_m1_splb                                          ...
# tss_1r_m1_splc                                          ...
# tss_1r_m1_spld                                          ...
# tss_1r_m1_spmf                                          ...
# tss_1r_m1_spop                                          ...
# tss_1r_m1_spsa                                          ...
# tss_1r_m1_spsb                                          ...
# tss_1r_m1_spsc                                          ...
# tss_1r_m1_spsd                                          ...
# tss_1r_m1_staa                                          ...
# tss_1r_m1_stca                                          ...
# tss_1r_m1_stcb                                          ...
# tss_1r_m1_stcc                                          ...
# tss_1r_m1_stcd                                          ...
# tss_1r_m1_stda                                          ...
# tss_1r_m1_stdb                                          ...
# tss_1r_m1_stdc                                          ...
# tss_1r_m1_stfa                                          ...
# tss_1r_m1_stfb                                          ...
# tss_1r_m1_stma                                          ...
# tss_1r_m1_stmb                                          ...
# tss_1r_m1_stsa                                          ...
# tss_1r_m1_stsb                                          ...
# tss_1r_m1_stsc                                          ...
# tss_1r_m1_stta                                          ...
# tss_1r_m1_sttb                                          ...
# tss_1r_m1_sttc                                          ...
# tss_1r_m1_sttd                                          ...
# tss_1r_m1_tmha                                          ...
# tss_1r_m1_tmhb                                          ...
# tss_1r_m1_tmmi                                          ...
# tss_1r_m1_tmmo                                          ...
# tss_1r_m1_tmta                                          ...
# tss_1r_r0_cas                                           ...
# tss_1r_r0_dcore                                         ...
# tss_1r_r0_dply                                          ...
# tss_1r_r0_drb                                           ...
# tss_1r_r0_emp                                           ...
# tss_1r_r0_rete                                          ...
# tss_1r_r0_rope                                          ...
# tss_1r_r0_sahk                                          ...
# tss_1r_r0_score                                         ...
# tss_1r_r0_sets                                          ...
# tss_1r_r0_spree                                         ...
# tss_1r_r0_temag                                         ...
# twins1_at_def                                           ...
# twins1_hk_1sec                                          ...
# twins1_l1_imager                                        ...
# twins1_l1_lad                                           ...
# twins1_or_def                                           ...
# twins1_tistorm_imager                                   ...
# twins2_at_def                                           ...
# twins2_hk_1sec                                          ...
# twins2_l1_imager                                        ...
# twins2_l1_lad                                           ...
# twins2_or_def                                           ...
# twins2_tistorm_imager                                   ...
# twins_m2_ena                                            ...
# ulysses_helio1day_position                              ...
# ulysses_helio1hr_position                               ...
# uranus_helio1day_position                               ...
# uranus_helio1hr_position                                ...
# uy_1min_vhm                                             ...
# uy_1sec_vhm                                             ...
# uy_alpha_distributions_swoops                           ...
# uy_alpha_fit_parameters_swoops                          ...
# uy_alpha_moments_swoops                                 ...
# uy_coho1hr_merged_mag_plasma                            ...
# uy_h0_glg                                               ...
# uy_m0_at1                                               ...
# uy_m0_at2                                               ...
# uy_m0_bae                                               ...
# uy_m0_bai                                               ...
# uy_m0_grb                                               ...
# uy_m0_het                                               ...
# uy_m0_hft                                               ...
# uy_m0_ket                                               ...
# uy_m0_let                                               ...
# uy_m0_pfra                                              ...
# uy_m0_pfrp                                              ...
# uy_m0_r144                                              ...
# uy_m0_rara                                              ...
# uy_m0_rarp                                              ...
# uy_m0_wfba                                              ...
# uy_m0_wfbp                                              ...
# uy_m0_wfea                                              ...
# uy_m0_wfep                                              ...
# uy_m1_bai                                               ...
# uy_m1_epa                                               ...
# uy_m1_lf15                                              ...
# uy_m1_lf60                                              ...
# uy_m1_lm12                                              ...
# uy_m1_lm30                                              ...
# uy_m1_lmde                                              ...
# uy_m1_scs                                               ...
# uy_m1_swi                                               ...
# uy_m1_vhm                                               ...
# uy_m1_wart                                              ...
# uy_m1_wrtd                                              ...
# uy_proton_distributions_swoops                          ...
# uy_proton_fit_parameters_swoops                         ...
# uy_proton_moments_swoops                                ...
# venus_helio1day_position                                ...
# venus_helio1hr_position                                 ...
# vg1_pws_lr                                              ...
# vg1_pws_wf                                              ...
# vg2_pws_lr                                              ...
# vg2_pws_wf                                              ...
# voyager1_10s_mag                                        ...
# voyager1_1hr_mag                                        ...
# voyager1_2s_mag                                         ...
# voyager1_48s_mag                                        ...
# voyager1_48s_mag_vim                                    ...
# voyager1_coho1hr_merged_mag_plasma                      ...
# voyager1_crs_daily_flux                                 ...
# voyager1_pls_composition                                ...
# voyager1_pls_electrons_e1                               ...
# voyager1_pls_electrons_e2                               ...
# voyager1_pls_hires_plasma_data                          ...
# voyager1_pls_ions_l                                     ...
# voyager1_pls_ions_m                                     ...
# voyager2_10s_mag                                        ...
# voyager2_1hr_mag                                        ...
# voyager2_2s_mag                                         ...
# voyager2_48s_mag                                        ...
# voyager2_48s_mag_vim                                    ...
# voyager2_coho1hr_merged_mag_plasma                      ...
# voyager2_pls_composition                                ...
# voyager2_pls_electrons_e1                               ...
# voyager2_pls_electrons_e2                               ...
# voyager2_pls_hires_plasma_data                          ...
# voyager2_pls_hires_plasma_data_hsh                      ...
# voyager2_pls_ions_l                                     ...
# voyager2_pls_ions_m                                     ...
# voyager_1_lecp_elec_bgnd_cor_1d                         ...
# voyager_1_lecp_lev_1_rates                              ...
# voyager_1_lecp_lev_2_daily_avg                          ...
# voyager_1_lecp_lev_2_hourly_avg                         ...
# voyager_1_lecp_lev_2_scan_avg                           ...
# voyager_2_lecp_elec_bgnd_cor_1d                         ...
# voyager_2_lecp_lev_1_rates                              ...
# voyager_2_lecp_lev_2_daily_avg                          ...
# voyager_2_lecp_lev_2_hourly_avg                         ...
# voyager_2_lecp_lev_2_scan_avg                           ...
# wi_at_def                                               ...
# wi_at_pre                                               ...
# wi_ehpd_3dp                                             ...
# wi_ehsp_3dp                                             ...
# wi_elm2_3dp                                             ...
# wi_elpd_3dp                                             ...
# wi_elsp_3dp                                             ...
# wi_em_3dp                                               ...
# wi_emfits_e0_3dp                                        ...
# wi_epact_step_differential_ion_flux_1hr                 ...
# wi_epact_step_directional_diff_cno_flux_10min           ...
# wi_epact_step_directional_diff_fe_flux_10min            ...
# wi_epact_step_directional_diff_h_flux_10min             ...
# wi_epact_step_directional_diff_he_flux_10min            ...
# wi_h0_mfi                                               ...
# wi_h0_swe                                               ...
# wi_h0_wav                                               ...
# wi_h1_swe                                               ...
# wi_h1_swe_rtn                                           ...
# wi_h1_wav                                               ...
# wi_h2_mfi                                               ...
# wi_h3_rtn_mfi                                           ...
# wi_h3_swe                                               ...
# wi_h4_rtn_mfi                                           ...
# wi_h4_swe                                               ...
# wi_h5_swe                                               ...
# wi_k0_3dp                                               ...
# wi_k0_epa                                               ...
# wi_k0_gifwalk                                           ...
# wi_k0_mfi                                               ...
# wi_k0_sms                                               ...
# wi_k0_spha                                              ...
# wi_k0_swe                                               ...
# wi_k0_swe_rtn                                           ...
# wi_k0_wav                                               ...
# wi_k1_rtn_mfi                                           ...
# wi_l2_1hour_sep_epact_ape_b                             ...
# wi_l2_1hour_sep_epact_lemt                              ...
# wi_l2_30min_sms_stics_afm_magnetosphere                 ...
# wi_l2_30min_sms_stics_afm_solarwind                     ...
# wi_l2_30min_sms_stics_erpa_magnetosphere                ...
# wi_l2_30min_sms_stics_erpa_solarwind                    ...
# wi_l2_3min_sms_stics_nvt_magnetosphere                  ...
# wi_l2_3min_sms_stics_nvt_solarwind                      ...
# wi_l2_3min_sms_stics_vdf_magnetosphere                  ...
# wi_l2_3min_sms_stics_vdf_solarwind                      ...
# wi_l2_5min_sep_epact_lemt                               ...
# wi_l2_wav_rad1                                          ...
# wi_l2_wav_rad2                                          ...
# wi_l3_dustimpact_waves                                  ...
# wi_m0_swe                                               ...
# wi_m2_swe                                               ...
# wi_or_def                                               ...
# wi_or_gifwalk                                           ...
# wi_or_pre                                               ...
# wi_plsp_3dp                                             ...
# wi_pm_3dp                                               ...
# wi_sfpd_3dp                                             ...
# wi_sfsp_3dp                                             ...
# wi_sopd_3dp                                             ...
# wi_sosp_3dp                                             ...
# wi_strahl0_swe                                          ...
# wi_sw_ion_dist_swe_faraday                              ...
# wi_wa_rad1_l3_df                                        ...
# wild2_helio1day_position                                ...
# wild2_helio1hr_position                                 ...
# wind_3dp_echsfits_e0_yr                                 ...
# wind_helio1hr_position                                  ...
# wind_waves_qtnfit                                       ...
# wind_waves_qtnfit_filtered                              ...

# %% [markdown]
# Next download with Fido:

# %%
rfs_files = Fido.fetch(query)
# Out:
# Files Downloaded:   0%|          | 0/2 [00:00<?, ?file/s]

# %% [markdown]
# Load in the RFS files by passing the downloaded files to `radiospectra.Spectrogram` :

# %%
rfs_Spectrograms = Spectrogram(rfs_files)

# %% [markdown]
# Next, plot the RFS data we loaded:
#
# (Note that this plots two spectrograms (RFS HFR and RFS LFR) on the same axes.)

# %%
fig,ax = plt.subplots(figsize=(10,6))
[spec.plot(axes=ax,
           norm=LogNorm(spec.data.value.min(),spec.data.value.max()), # Log-Normalize Colorscale
           cmap="RdYlBu_r") # Colormap from Nedat+2026
 for spec in rfs_Spectrograms]
ax.set_xlim(dt_start,dt_end)
ax.set_yscale("log")

# %% [markdown]
# ### Combining Ground and Space Observations of the Same Event
#
# Finally, we can combine these plots to show the progression of the event from the low corona out into the solar wind.
#
# The most straightforward way to do this is to just create two subplots, which avoids issues with units:

# %%
fig,(ax1,ax2) = plt.subplots(figsize=(10,10),nrows=2,sharex=True)

[spec.plot(axes=ax1,
           norm=LogNorm(spec.data.min(),spec.data.max()), # Log-Normalize Colorscale
           cmap="RdYlBu_r") # Colormap from Nedat+2026
 for spec in ilofar_Spectrograms]

[spec.plot(axes=ax2,
           norm=LogNorm(spec.data.value.min(),spec.data.value.max()), # Log-Normalize Colorscale
           cmap="RdYlBu_r") # Colormap from Nedat+2026
 for spec in rfs_Spectrograms]

for ax in [ax1,ax2] : 
    ax.set_xlim(dt_start,dt_end)
    ax.set_yscale("log")
    
ax1.set_ylabel("Frequency (MHz)")
ax2.set_ylabel("Frequency (Hz)")
# Out:
# Text(0, 0.5, 'Frequency (Hz)')

# %% [markdown]
# Note a small time offset between the Parker and I-LOFAR observations: Parker receives photons from the event ~3 min earlier than I-LOFAR due to being located at about 0.7au during the event.
#
# At present, the `Radiospectra` `Spectrogram` class doesn't provide a method for this time shift or other time/frequency slicing capabilities, but these are in the works amongst the below issues.

# %% [markdown]
# ### Noted Problems and Related GitHub Issues

# %% [markdown]
# * i-LOFAR Fido search - https://github.com/sunpy/radiospectra/issues/200
# * RFS L3 data access - https://github.com/sunpy/radiospectra/issues/203
# * Unit mismatch - Fixed in bleeding edge
# * Timeshift - https://github.com/sunpy/radiospectra/issues/205
# * Flux units - https://github.com/sunpy/radiospectra/issues/204
